# %% [markdown]
# # Webscraping NBA Data

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Empty list to put in appended dataframes in
df_list = []
# List of years to input in the outermost for loop
years = ['2010-11', '2012-13', '2013-14', '2014-15', '2015-16', '2016-17', '2017-18', '2018-19']
# List of months to input in the second for loop
months = ['October', 'November', 'December', 'January', 'February', 'March', 'April']
# List of column headers to input in the innermost for loop
columns = ['Starters','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','+/-']

# Outermost for loop used to loop through every regular season except for the 2011-12 season because that year was shortened
for h in range(0, len(years)):
    # Code that allows you to click on the basketball reference website
    driver = webdriver.Chrome(executable_path='C:/Users/yesla/bin/chromedriver.exe')
    driver.get("https://www.basketball-reference.com/leagues/")
    # Code that finds the particular NBA season in this iteration
    driver.find_element_by_link_text(years[h]).click()
    # Clicks on the 'Schedule and Results' section of the page
    driver.find_element_by_link_text("Schedule and Results").click()
    for i in range(0, len(months)):
        # Get all of the box scores for October in the 2010-2011 season
        driver.find_element_by_link_text(months[i]).click()
        allgames = driver.find_element_by_id("schedule")
        tr_list = allgames.find_elements_by_tag_name('tr')
    
        # First for loop to get the first 30 boxscores
        if months[i] != 'April':
            for j in range(1,len(tr_list)):
            # Use try statement to get passed the weird table formatting
                try:
                    # Click on the boxscores for the NBA games
                    allgames = driver.find_element_by_id("schedule")
                    tr_list = allgames.find_elements_by_tag_name('tr')
                    tr_list[j].find_element_by_link_text("Box Score").click()
    
                    # Get team names for later use
                    soup = BeautifulSoup(driver.page_source, 'html.parser')
                    table = soup.find(name='table', attrs={'id':'line_score'})
                    html_str = str(table)
                    df = pd.read_html(html_str)[0]
                    team1 = df['Unnamed: 0'][1]
                    team2 = df['Unnamed: 0'][2]
    
                    # Extract and transform first teams boxscore
                    table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
                    html_str1 = str(table1)
                    df1 = pd.read_html(html_str1)[0]
                    df1 = pd.DataFrame(df1.to_records())
                    first_column = df1.columns[0]
                    df1 = df1.drop([first_column], axis=1)
                    df1.columns = columns
                    df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
    
                    # Extract and transform second teams boxscore
                    table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
                    html_str2 = str(table2)
                    df2 = pd.read_html(html_str2)[0]
                    df2 = pd.DataFrame(df2.to_records())
                    first_column = df2.columns[0]
                    df2 = df2.drop([first_column], axis=1)
                    df2.columns = columns
                    df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]
    
                    # Concatenate both boxscores then append to empty list
                    df_comp = pd.concat([df1,df2])
                    df_list.append(df_comp)
                    driver.back()
                except:
                    pass
        else:
            for j in range(60,len(tr_list)):
            # Use try statement to get passed the weird table formatting
                try:
                    # Click on the boxscores for the NBA games
                    allgames = driver.find_element_by_id("schedule")
                    tr_list = allgames.find_elements_by_tag_name('tr')
                    tr_list[j].find_element_by_link_text("Box Score").click()
    
                    # Get team names for later use
                    soup = BeautifulSoup(driver.page_source, 'html.parser')
                    table = soup.find(name='table', attrs={'id':'line_score'})
                    html_str = str(table)
                    df = pd.read_html(html_str)[0]
                    team1 = df['Unnamed: 0'][1]
                    team2 = df['Unnamed: 0'][2]
    
                    # Extract and transform first teams boxscore
                    table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
                    html_str1 = str(table1)
                    df1 = pd.read_html(html_str1)[0]
                    df1 = pd.DataFrame(df1.to_records())
                    first_column = df1.columns[0]
                    df1 = df1.drop([first_column], axis=1)
                    df1.columns = columns
                    df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
    
                    # Extract and transform second teams boxscore
                    table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
                    html_str2 = str(table2)
                    df2 = pd.read_html(html_str2)[0]
                    df2 = pd.DataFrame(df2.to_records())
                    first_column = df2.columns[0]
                    df2 = df2.drop([first_column], axis=1)
                    df2.columns = columns
                    df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]
    
                    # Concatenate both boxscores then append to empty list
                    df_comp = pd.concat([df1,df2])
                    df_list.append(df_comp)
                    driver.back()
                except:
                    break

# %% [markdown]
# # 2011-2012 NBA Regular Season Data

# %%
# Code opens the basketball reference website and clicks on the schedule and results section of the 2011-2012 season
driver = webdriver.Chrome(executable_path='C:/Users/yesla/bin/chromedriver.exe')
driver.implicitly_wait(1)
driver.get("https://www.basketball-reference.com/leagues/")
driver.find_element_by_link_text('2011-12').click()
driver.find_element_by_link_text("Schedule and Results").click()

df_list2 = []
months2 = ['december', 'january', 'february', 'march', 'april']
columns = ['Starters','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','+/-']

for i in range(0, len(months2)):
    # Get all of the box scores for October in the 2010-2011 season
    driver.get('https://www.basketball-reference.com/leagues/NBA_2012_games-'+months2[i]+'.html')
    allgames = driver.find_element_by_id("schedule")
    tr_list = allgames.find_elements_by_tag_name('tr')
    
    # First for loop to get the first 30 boxscores
    if months2[i] != 'april':
        for j in range(1,len(tr_list)):
        # Use try statement to get passed the weird table formatting
            try:
                # Click on the boxscores for the NBA games
                allgames = driver.find_element_by_id("schedule")
                tr_list = allgames.find_elements_by_tag_name('tr')
                tr_list[j].find_element_by_link_text("Box Score").click()
    
                # Get team names for later use
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                table = soup.find(name='table', attrs={'id':'line_score'})
                html_str = str(table)
                df = pd.read_html(html_str)[0]
                team1 = df['Unnamed: 0'][1]
                team2 = df['Unnamed: 0'][2]
    
                # Extract and transform first teams boxscore
                table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
                html_str1 = str(table1)
                df1 = pd.read_html(html_str1)[0]
                df1 = pd.DataFrame(df1.to_records())
                first_column = df1.columns[0]
                df1 = df1.drop([first_column], axis=1)
                df1.columns = columns
                df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
    
                # Extract and transform second teams boxscore
                table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
                html_str2 = str(table2)
                df2 = pd.read_html(html_str2)[0]
                df2 = pd.DataFrame(df2.to_records())
                first_column = df2.columns[0]
                df2 = df2.drop([first_column], axis=1)
                df2.columns = columns
                df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]
    
                # Concatenate both boxscores then append to empty list
                df_comp = pd.concat([df1,df2])
                df_list2.append(df_comp)
                driver.back()
            except:
                pass
    else:
        for j in range(1,len(tr_list)):
        # Use try statement to get passed the weird table formatting
            try:
                # Click on the boxscores for the NBA games
                allgames = driver.find_element_by_id("schedule")
                tr_list = allgames.find_elements_by_tag_name('tr')
                tr_list[j].find_element_by_link_text("Box Score").click()
    
                # Get team names for later use
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                table = soup.find(name='table', attrs={'id':'line_score'})
                html_str = str(table)
                df = pd.read_html(html_str)[0]
                team1 = df['Unnamed: 0'][1]
                team2 = df['Unnamed: 0'][2]
    
                # Extract and transform first teams boxscore
                table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
                html_str1 = str(table1)
                df1 = pd.read_html(html_str1)[0]
                df1 = pd.DataFrame(df1.to_records())
                first_column = df1.columns[0]
                df1 = df1.drop([first_column], axis=1)
                df1.columns = columns
                df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
    
                # Extract and transform second teams boxscore
                table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
                html_str2 = str(table2)
                df2 = pd.read_html(html_str2)[0]
                df2 = pd.DataFrame(df2.to_records())
                first_column = df2.columns[0]
                df2 = df2.drop([first_column], axis=1)
                df2.columns = columns
                df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]
    
                # Concatenate both boxscores then append to empty list
                df_comp = pd.concat([df1,df2])
                df_list2.append(df_comp)
                driver.back()
            except:
                break

# %%
# Concatenates all of the extracted box score df's and then exports the concatenated df into a csv file for the next part
df_full = pd.concat(df_list2)
df_full.to_csv(r'C:\Users\yesla\OneDrive\Documents\GitHub\predicting-nba-games\df-2011-12.csv', index = False)
df_full
# Out:
#              Starters                MP   FG  FGA    FG%   3P  3PA    3P%  \
# 0         Rajon Rondo             41:16   11   19   .579    0    1   .000
# 1           Ray Allen             37:42    7   12   .583    2    3   .667
# 2       Kevin Garnett             37:03    6   13   .462    0    0    NaN
# 3     Jermaine O'Neal             17:11    2    5   .400    0    0    NaN
# 4      Sasha Pavlović             15:07    0    0    NaN    0    0    NaN
# 6     Marquis Daniels             29:48    2    8   .250    0    1   .000
# 7        Brandon Bass             27:36    9   13   .692    0    0    NaN
# 8        Chris Wilcox             14:03    2    3   .667    0    0    NaN
# 9       Keyon Dooling             11:23    0    1   .000    0    0    NaN
# 10      Avery Bradley              8:49    0    2   .000    0    0    NaN
# 11      E'Twaun Moore              0:04    0    0    NaN    0    0    NaN
# 0      Tyson Chandler             36:48    1    2   .500    0    0    NaN
# ...

# %% [markdown]
# # Code used when developing final code

# %%
df_full = pd.concat(df_list,df_list2)
df_full

# %%
team1
# Out:
# 'BOS'

# %%
# Extract and transform first teams boxscore
table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
html_str1 = str(table1)
df1 = pd.read_html(html_str1)[0]
df1 = pd.DataFrame(df1.to_records())
first_column = df1.columns[0]
df1 = df1.drop([first_column], axis=1)
df1.columns = columns
df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
    
# Extract and transform second teams boxscore
table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
html_str2 = str(table2)
df2 = pd.read_html(html_str2)[0]
df2 = pd.DataFrame(df2.to_records())
first_column = df2.columns[0]
df2 = df2.drop([first_column], axis=1)
df2.columns = columns
df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5afa92e088b9> in <module>()
#       6 first_column = df1.columns[0]
#       7 df1 = df1.drop([first_column], axis=1)
# ----> 8 df1.columns = columns
#       9 df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]
#      10
#
# NameError: name 'columns' is not defined

# %%
driver.find_element_by_link_text('October').click()

# %%
allgames = driver.find_element_by_id("schedule")
tr_list = allgames.find_elements_by_tag_name('tr')
tr_list[44].find_element_by_link_text("Box Score").click()
driver.back()

# %%
allgames = driver.find_element_by_id("schedule")
tr_list = allgames.find_elements_by_tag_name('tr')
len(tr_list)
# Out:
# 45

# %%
for i in range(29,33):
    # Click on the boxscores for the NBA games
    try:
        allgames = driver.find_element_by_id("schedule")
        tr_list = allgames.find_elements_by_tag_name('tr')
        tr_list[i].find_element_by_link_text("Box Score").click()
        driver.back()
    except:
        pass

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
table = soup.find(name='table', attrs={'id':'line_score'})
html_str = str(table)
df = pd.read_html(html_str)[0]
team1 = df['Unnamed: 0'][1]
team2 = df['Unnamed: 0'][2]

# %%
columns = ['Starters','MP','FG','FGA','FG%','3P','3PA','3P%','FT','FTA','FT%','ORB','DRB','TRB','AST','STL','BLK','TOV','PF','PTS','+/-']

# %%
table1 = soup.find(name='table', attrs={'id':'box-'+team1+'-game-basic'})
html_str1 = str(table1)
df1 = pd.read_html(html_str1)[0]
df1
# Out:
#     Unnamed: 0_level_0 Basic Box Score Stats Unnamed: 2_level_0  \
#               Starters                    MP                 FG
# 0         LeBron James                 42:39                 10
# 1           Chris Bosh                 37:37                  3
# 2          Dwyane Wade                 36:41                  4
# 3         Joel Anthony                 16:41                  1
# 4        Carlos Arroyo                 12:33                  1
# 5             Reserves                    MP                 FG
# 6        Udonis Haslem                 30:36                  3
# 7          Eddie House                 26:30                  3
# 8          James Jones                 26:04                  2
# 9   Zydrunas Ilgauskas                 10:39                  0
# 10     Jamaal Magloire          Did Not Play                NaN
# 11        Juwan Howard          Did Not Play                NaN
# 12      Mario Chalmers          Did Not Play                NaN
# ...

# %%
df1 = pd.DataFrame(df1.to_records())

# %%
first_column = df1.columns[0]
df1 = df1.drop([first_column], axis=1)
df1
# Out:
#    ('Unnamed: 0_level_0', 'Starters') ('Basic Box Score Stats', 'MP')  \
# 0                        LeBron James                           42:39
# 1                          Chris Bosh                           37:37
# 2                         Dwyane Wade                           36:41
# 3                        Joel Anthony                           16:41
# 4                       Carlos Arroyo                           12:33
# 5                            Reserves                              MP
# 6                       Udonis Haslem                           30:36
# 7                         Eddie House                           26:30
# 8                         James Jones                           26:04
# 9                  Zydrunas Ilgauskas                           10:39
# 10                    Jamaal Magloire                    Did Not Play
# 11                       Juwan Howard                    Did Not Play
# ...

# %%
df1.columns = columns
df1 = df1[(df1['Starters'] != 'Reserves') & (df1['Starters'] != 'Team Totals') & (df1['MP'] != 'Did Not Play')]

# %%
table2 = soup.find(name='table', attrs={'id':'box-'+team2+'-game-basic'})
html_str2 = str(table2)
df2 = pd.read_html(html_str2)[0]
df2 = pd.DataFrame(df2.to_records())
first_column = df2.columns[0]
df2 = df2.drop([first_column], axis=1)
df2.columns = columns
df2 = df2[(df2['Starters'] != 'Reserves') & (df2['Starters'] != 'Team Totals') & (df2['MP'] != 'Did Not Play')]

# %%
df2
# Out:
#             Starters                MP   FG  FGA   FG%   3P  3PA   3P%   FT  \
# 0        Rajon Rondo             41:29    2    9  .222    0    0   NaN    0
# 1        Paul Pierce             40:33    4    7  .571    3    4  .750    8
# 2          Ray Allen             39:16    7   13  .538    5    8  .625    1
# 3      Kevin Garnett             35:13    4   11  .364    0    0   NaN    2
# 4   Shaquille O'Neal             18:09    3    7  .429    0    0   NaN    3
# 6         Glen Davis             29:24    6    7  .857    0    0   NaN    1
# 7    Marquis Daniels             12:49    4    5  .800    0    1  .000    0
# 8    Jermaine O'Neal             12:47    0    3  .000    0    0   NaN    1
# 9      Nate Robinson             10:20    2    7  .286    0    3  .000    0
# 10      Delonte West  Player Suspended  NaN  NaN   NaN  NaN  NaN   NaN  NaN
#
#     FTA ...   ORB  DRB  TRB  AST  STL  BLK  TOV   PF  PTS  +/-
# 0     0 ...     1    4    5   17    2    0    3    1    4   +4
# ...

# %%
df_comp = pd.concat([df1,df2])
df_comp
# Out:
#               Starters                MP   FG  FGA    FG%   3P  3PA   3P%  \
# 0         LeBron James             42:39   10   21   .476    3    6  .500
# 1           Chris Bosh             37:37    3   11   .273    0    0   NaN
# 2          Dwyane Wade             36:41    4   16   .250    1    3  .333
# 3         Joel Anthony             16:41    1    1  1.000    0    0   NaN
# 4        Carlos Arroyo             12:33    1    3   .333    0    0   NaN
# 6        Udonis Haslem             30:36    3    7   .429    0    0   NaN
# 7          Eddie House             26:30    3    8   .375    2    4  .500
# 8          James Jones             26:04    2    7   .286    2    7  .286
# 9   Zydrunas Ilgauskas             10:39    0    0    NaN    0    0   NaN
# 0          Rajon Rondo             41:29    2    9   .222    0    0   NaN
# 1          Paul Pierce             40:33    4    7   .571    3    4  .750
# 2            Ray Allen             39:16    7   13   .538    5    8  .625
# ...
